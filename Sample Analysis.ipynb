# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## R.Edwin Moses
# Subject Matter Expert

# %% [markdown]
# I am interested in data science because mitigating risk and fraud...Delivering relevant products...personalized customer experiences

# %% [markdown]
# ### I write basic addition program we can use this code to make addition calculation

# %%
print(1+1)
# Out:
# 2

# %% [markdown]
# ![Screenshot%20from%202021-02-17%2000-28-10.png](attachment:Screenshot%20from%202021-02-17%2000-28-10.png)
